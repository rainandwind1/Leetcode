# %%
class Solution(object):
    def climbStairs(self, n):
        """
        :type n: int
        :rtype: int
        """
#         print(n)
        if n == 1:
            return 1
        elif n == 2:
            return 2
        return self.climbStairs(n - 1) + self.climbStairs(n - 2)

A = Solution()
print(A.climbStairs(38))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-76a3e2a79685> in <module>
#      13
#      14 A = Solution()
# ---> 15 print(A.climbStairs(38))
#
# <ipython-input-7-76a3e2a79685> in climbStairs(self, n)
#      10         elif n == 2:
#      11             return 2
# ---> 12         return self.climbStairs(n - 1) + self.climbStairs(n - 2)
#      13
#      14 A = Solution()
#
# <ipython-input-7-76a3e2a79685> in climbStairs(self, n)
#      10         elif n == 2:
#      11             return 2
# ---> 12         return self.climbStairs(n - 1) + self.climbStairs(n - 2)
#      13
#      14 A = Solution()
#
# <ipython-input-7-76a3e2a79685> in climbStairs(self, n)
#      10         elif n == 2:
#      11             return 2
# ---> 12         return self.climbStairs(n - 1) + self.climbStairs(n - 2)
#      13
#      14 A = Solution()
#
# <ipython-input-7-76a3e2a79685> in climbStairs(self, n)
#      10         elif n == 2:
#      11             return 2
# ---> 12         return self.climbStairs(n - 1) + self.climbStairs(n - 2)
#      13
#      14 A = Solution()
#
# <ipython-input-7-76a3e2a79685> in climbStairs(self, n)
#      10         elif n == 2:
#      11             return 2
# ---> 12         return self.climbStairs(n - 1) + self.climbStairs(n - 2)
#      13
#      14 A = Solution()
#
# <ipython-input-7-76a3e2a79685> in climbStairs(self, n)
#      10         elif n == 2:
#      11             return 2
# ---> 12         return self.climbStairs(n - 1) + self.climbStairs(n - 2)
#      13
#      14 A = Solution()
#
# <ipython-input-7-76a3e2a79685> in climbStairs(self, n)
#      10         elif n == 2:
#      11             return 2
# ---> 12         return self.climbStairs(n - 1) + self.climbStairs(n - 2)
#      13
#      14 A = Solution()
#
# <ipython-input-7-76a3e2a79685> in climbStairs(self, n)
#      10         elif n == 2:
#      11             return 2
# ---> 12         return self.climbStairs(n - 1) + self.climbStairs(n - 2)
#      13
#      14 A = Solution()
#
# <ipython-input-7-76a3e2a79685> in climbStairs(self, n)
#      10         elif n == 2:
#      11             return 2
# ---> 12         return self.climbStairs(n - 1) + self.climbStairs(n - 2)
#      13
#      14 A = Solution()
#
# <ipython-input-7-76a3e2a79685> in climbStairs(self, n)
#      10         elif n == 2:
#      11             return 2
# ---> 12         return self.climbStairs(n - 1) + self.climbStairs(n - 2)
#      13
#      14 A = Solution()
#
# <ipython-input-7-76a3e2a79685> in climbStairs(self, n)
#      10         elif n == 2:
#      11             return 2
# ---> 12         return self.climbStairs(n - 1) + self.climbStairs(n - 2)
#      13
#      14 A = Solution()
#
# <ipython-input-7-76a3e2a79685> in climbStairs(self, n)
#      10         elif n == 2:
#      11             return 2
# ---> 12         return self.climbStairs(n - 1) + self.climbStairs(n - 2)
#      13
#      14 A = Solution()
#
# <ipython-input-7-76a3e2a79685> in climbStairs(self, n)
#      10         elif n == 2:
#      11             return 2
# ---> 12         return self.climbStairs(n - 1) + self.climbStairs(n - 2)
#      13
#      14 A = Solution()
#
# <ipython-input-7-76a3e2a79685> in climbStairs(self, n)
#      10         elif n == 2:
#      11             return 2
# ---> 12         return self.climbStairs(n - 1) + self.climbStairs(n - 2)
#      13
#      14 A = Solution()
#
# <ipython-input-7-76a3e2a79685> in climbStairs(self, n)
#      10         elif n == 2:
#      11             return 2
# ---> 12         return self.climbStairs(n - 1) + self.climbStairs(n - 2)
#      13
#      14 A = Solution()
#
# <ipython-input-7-76a3e2a79685> in climbStairs(self, n)
#      10         elif n == 2:
#      11             return 2
# ---> 12         return self.climbStairs(n - 1) + self.climbStairs(n - 2)
#      13
#      14 A = Solution()
#
# <ipython-input-7-76a3e2a79685> in climbStairs(self, n)
#      10         elif n == 2:
#      11             return 2
# ---> 12         return self.climbStairs(n - 1) + self.climbStairs(n - 2)
#      13
#      14 A = Solution()
#
# <ipython-input-7-76a3e2a79685> in climbStairs(self, n)
#      10         elif n == 2:
#      11             return 2
# ---> 12         return self.climbStairs(n - 1) + self.climbStairs(n - 2)
#      13
#      14 A = Solution()
#
# <ipython-input-7-76a3e2a79685> in climbStairs(self, n)
#      10         elif n == 2:
#      11             return 2
# ---> 12         return self.climbStairs(n - 1) + self.climbStairs(n - 2)
#      13
#      14 A = Solution()
#
# <ipython-input-7-76a3e2a79685> in climbStairs(self, n)
#      10         elif n == 2:
#      11             return 2
# ---> 12         return self.climbStairs(n - 1) + self.climbStairs(n - 2)
#      13
#      14 A = Solution()
#
# <ipython-input-7-76a3e2a79685> in climbStairs(self, n)
#      10         elif n == 2:
#      11             return 2
# ---> 12         return self.climbStairs(n - 1) + self.climbStairs(n - 2)
#      13
#      14 A = Solution()
#
# <ipython-input-7-76a3e2a79685> in climbStairs(self, n)
#      10         elif n == 2:
#      11             return 2
# ---> 12         return self.climbStairs(n - 1) + self.climbStairs(n - 2)
#      13
#      14 A = Solution()
#
# <ipython-input-7-76a3e2a79685> in climbStairs(self, n)
#      10         elif n == 2:
#      11             return 2
# ---> 12         return self.climbStairs(n - 1) + self.climbStairs(n - 2)
#      13
#      14 A = Solution()
#
# KeyboardInterrupt:

# %%
class Solution:
    @functools.lru_cache(100)
    def climbStairs(self, n: int) -> int:
        if n == 1:
            return 1
        elif n == 2:
            return 2
        return self.climbStairs(n - 1) + self.climbStairs(n - 2)

# %%
class Solution(object):
    def climbStairs(self, n):
        """
        :type n: int
        :rtype: int
        """
        if n <= 2:
            return n
        dp = [0 for _ in range(n + 1)]
        dp[1] = 1
        dp[2] = 2
        for i in range(3, n + 1):
            dp[i] = dp[i - 1] + dp[i - 2]
        return dp[-1]

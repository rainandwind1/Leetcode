# %%
class Solution(object):
    def updateMatrix(self, matrix):
        """
        :type matrix: List[List[int]]
        :rtype: List[List[int]]
        """
        res = [[0 for i in range(len(matrix[0]))] for j in range(len(matrix))]
        def find_min(id_x, id_y, mem_x, mem_y, depth):
            print(id_x,id_y)
            if matrix[id_x][id_y] == 0:
                return depth
            else:
                up_depth = float('inf')
                left_depth = float('inf')
                right_depth = float('inf')
                down_depth = float('inf')
                
                if id_x - 1 >= 0:
                    if id_x - 1 < mem_x:
                        up_depth = 1 + res[id_x - 1][id_y]
                    elif id_x - 1 == mem_x and id_y <= mem_y:
                        up_depth = 1 + res[id_x - 1][id_y]
                    else:
                        up_depth = find_min(id_x - 1, id_y, mem_x, mem_y, depth + 1)
                
                if id_x + 1 < len(matrix):
                    down_depth = find_min(id_x + 1, id_y, mem_x, mem_y, depth + 1)
                
                if id_y - 1 >= 0:
                    if id_x - 1 < mem_x:
                        left_depth = 1 + res[id_x][id_y - 1]
                    elif id_x - 1 == mem_x and id_y <= mem_y:
                        left_depth = 1 + res[id_x][id_y - 1]
                    else:
                        left_depth = find_min(id_x, id_y - 1, mem_x, mem_y, depth + 1)           
                
                if id_y + 1 < len(matrix[0]):
                    right_depth = find_min(id_x, id_y + 1, mem_x, mem_y, depth + 1)
                
                return min(up_depth, left_depth, right_depth, down_depth)
        print(len(matrix),len(matrix[0]))
        for i in range(len(matrix)):
            for j in range(len(matrix[0])):
#                 print(i,j)
                res[i][j] = find_min(i, j, i, j, 0)
        return res

A = Solution()
print(A.updateMatrix([[0,0,0],
[0,1,0],
[1, 1, 1]]))
print(A.updateMatrix([[0],[0],[0],[0],[0]]))
# Out:
# 3 3
# 0 0
# 0 1
# 0 2
# 1 0
# 1 1
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# 2 2
# 1 2
# 2 1
# ...

# %%
# 官方解法
class Solution(object):
    def updateMatrix(self, matrix):
        """
        :type matrix: List[List[int]]
        :rtype: List[List[int]]
        """
        m, n = len(matrix), len(matrix[0])
        dist = [[0] * n for _ in range(m)]
        zeroes_pos = [(i, j) for i in range(m) for j in range(n) if matrix[i][j] == 0]
        # 将所有的 0 添加进初始队列中
        q = collections.deque(zeroes_pos)
        seen = set(zeroes_pos)

        # 广度优先搜索
        while q:
            i, j = q.popleft()
            for ni, nj in [(i - 1, j), (i + 1, j), (i, j - 1), (i, j + 1)]:
                if 0 <= ni < m and 0 <= nj < n and (ni, nj) not in seen:
                    dist[ni][nj] = dist[i][j] + 1
                    q.append((ni, nj))
                    seen.add((ni, nj))

        return dist

# %%
min(1,2,0.3,4)
# Out:
# 0.3
